# %% [markdown]
# ## Data Exploration

# %%
# Import Libraries and Datasets
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Human_Resources.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
# Check for missing data.
# df.isnull().sum()

# %%
# Get dataset info.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# 35 features in total, each contains 1470 data points

# %%
# Descriptive statistics.
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ## Exploratory Analysis

# %%
# Replace 'Attrition', 'overtime', 'Over18' columns with integers. 
df['Attrition'] = df.Attrition.map(lambda x: 1 if x == 'Yes' else 0)
df['OverTime'] = df.OverTime.map(lambda x: 1 if x == 'Yes' else 0)
df['Over18'] = df.Over18.map(lambda x: 1 if x == 'Y' else 0)

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
 # Check for missing data.
 sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
 plt.show()

# %%
# Check for distribution.
# Several features are tail heavy.
df.hist(bins = 30, figsize = (20,20), color = 'purple')
plt.show()

# %%
# Drop 'EmployeeCount' , 'Standardhours' and 'Over18' since they do not change from one employee to the other.
df = df.drop(columns=['EmployeeCount', 'StandardHours', 'Over18', 'EmployeeNumber'], axis=1)
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# ...

# %%
# Check the number of employees who stayed and left.
# It seems the dataset is imbalanced. 
sns.countplot(x='Attrition', data=df)
plt.show()

# %%
df.groupby('Attrition').mean()
# Out:
#                  Age   DailyRate  DistanceFromHome  Education  \
# Attrition
# 0          37.561233  812.504461          8.915653   2.927007
# 1          33.607595  750.362869         10.632911   2.839662
#
#            EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# Attrition
# 0                         2.771290   65.952149        2.770479  2.145985
# 1                         2.464135   65.573840        2.518987  1.637131
#
#            JobSatisfaction  MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# Attrition
# 0                 2.778589    6832.739659  14265.779400            2.645580
# 1                 2.468354    4787.092827  14559.308017            2.940928
#
#            OverTime  PercentSalaryHike  PerformanceRating  \
# Attrition
# 0          0.234388          15.231144           3.153285
# 1          0.535865          15.097046           3.156118
#
#            RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# Attrition
# ...

# %%
# Stayed employees have higher average age, distance from home, job level, environment satisfication, and job statisfaction.
# Stayed employees have higher average monthly income, stock option level, and overall total years.
# Stayed employees have lesser over time.

# %%
# Employees that left.
left_df = df[df.Attrition==1]
left_df.describe()
# Out:
#               Age  Attrition    DailyRate  DistanceFromHome   Education  \
# count  237.000000      237.0   237.000000        237.000000  237.000000
# mean    33.607595        1.0   750.362869         10.632911    2.839662
# std      9.689350        0.0   401.899519          8.452525    1.008244
# min     18.000000        1.0   103.000000          1.000000    1.000000
# 25%     28.000000        1.0   408.000000          3.000000    2.000000
# 50%     32.000000        1.0   699.000000          9.000000    3.000000
# 75%     39.000000        1.0  1092.000000         17.000000    4.000000
# max     58.000000        1.0  1496.000000         29.000000    5.000000
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement    JobLevel  \
# count               237.000000  237.000000      237.000000  237.000000
# mean                  2.464135   65.573840        2.518987    1.637131
# std                   1.169791   20.099958        0.773405    0.940594
# ...

# %%
# Employees that stayed.
stayed_df = df[df.Attrition==0]
stayed_df.describe()
# Out:
#                Age  Attrition    DailyRate  DistanceFromHome    Education  \
# count  1233.000000     1233.0  1233.000000       1233.000000  1233.000000
# mean     37.561233        0.0   812.504461          8.915653     2.927007
# std       8.888360        0.0   403.208379          8.012633     1.027002
# min      18.000000        0.0   102.000000          1.000000     1.000000
# 25%      31.000000        0.0   477.000000          2.000000     2.000000
# 50%      36.000000        0.0   817.000000          7.000000     3.000000
# 75%      43.000000        0.0  1176.000000         13.000000     4.000000
# max      60.000000        0.0  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1233.000000  1233.000000     1233.000000  1233.000000
# mean                  2.771290    65.952149        2.770479     2.145985
# std                   1.071132    20.380754        0.692050     1.117933
# ...

# %%
# Correlations of each features.
corr = df.corr()
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(corr, annot = True)
plt.show()

# %%
# JobLevel, TotalWorkingYears, and MonthlyIncome are strongly correlated.
# YearsAtcompany, YearsWithCurrManager, and YearsInCurrentRole are strongly correlated.
# Age is stongly correlated with TotalWorkingYears.

# %%
# Age vs. Attrition.
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

plt.figure(figsize=[25, 12])
sns.countplot(x='Age', hue='Attrition', data = df)
plt.show()

# %%
# Analyze categorical features vs. Attrition.
plt.figure(figsize=[20,20])
# 411 - 4 rows by 1 columns and position.
plt.subplot(411)
sns.countplot(x = 'JobRole', hue = 'Attrition', data = df)
plt.subplot(412)
sns.countplot(x = 'MaritalStatus', hue = 'Attrition', data = df)
plt.subplot(413)
sns.countplot(x = 'JobInvolvement', hue = 'Attrition', data = df)
plt.subplot(414)
sns.countplot(x = 'JobLevel', hue = 'Attrition', data = df)
# Out:
# <Axes: xlabel='JobLevel', ylabel='count'>

# %%
# Sales Representitives tend to leave compared to other jobs.
# Single employees tend to leave compared to married and divorced.
# Less experienced (low job level) tend to leave.

# %%
# KDE (Kernel Density Estimate) is used for visualizing the Probability Density of a continuous variable. 
# KDE describes the probability density at different values in a continuous variable. 

plt.figure(figsize=(10,5))

sns.kdeplot(left_df['DistanceFromHome'], label='Employees who left', shade=True, color='r')
sns.kdeplot(stayed_df['DistanceFromHome'], label='Employees who Stayed', shade=True, color='b')

plt.xlabel('Distance From Home')
plt.show()
# Out:
# <ipython-input-23-17bbf2ddf8ee>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(left_df['DistanceFromHome'], label='Employees who left', shade=True, color='r')
# <ipython-input-23-17bbf2ddf8ee>:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(stayed_df['DistanceFromHome'], label='Employees who Stayed', shade=True, color='b')

# %%
plt.figure(figsize=(10,5))

sns.kdeplot(left_df['TotalWorkingYears'], label='Employees who left', shade=True, color='r')
sns.kdeplot(stayed_df['TotalWorkingYears'], label='Employees who stayed', shade=True, color='b')

plt.xlabel('Total Working Years')
plt.show()
# Out:
# <ipython-input-24-d532434d2060>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(left_df['TotalWorkingYears'], label='Employees who left', shade=True, color='r')
# <ipython-input-24-d532434d2060>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(stayed_df['TotalWorkingYears'], label='Employees who stayed', shade=True, color='b')

# %%
# MonthlyIncome vs. Gender.
plt.figure(figsize=(10, 5))
sns.boxplot(x='MonthlyIncome', y='Gender', data=df)
plt.show()

# %%
# MonthlyIncome vs. JobRole
plt.figure(figsize=(15, 10))
sns.boxplot(x='MonthlyIncome', y='JobRole', data=df)
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
# Encode categorical variables.
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()

enc_df = df
enc_df['businessTravel'] = ord_enc.fit_transform(df[['BusinessTravel']])
enc_df['department'] = ord_enc.fit_transform(df[['Department']])
enc_df['educationField'] = ord_enc.fit_transform(df[['EducationField']])
enc_df['gender'] = ord_enc.fit_transform(df[['Gender']])
enc_df['jobRole'] = ord_enc.fit_transform(df[['JobRole']])
enc_df['maritalStatus'] = ord_enc.fit_transform(df[['MaritalStatus']])

# %%
# Drop original categorical variables.
enc_df = enc_df.drop(['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus'], axis=1)

# %%
enc_df.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0   41          1       1102                 1          2
# 1   49          0        279                 8          1
# 2   37          1       1373                 2          2
# 3   33          0       1392                 3          4
# 4   27          0        591                 2          1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#    JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0                4           5993        19479                   8         1
# ...

# %%
# Scale the data and define x and y.
x = enc_df.drop('Attrition', axis=1)
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(x)
y = enc_df.Attrition

# %% [markdown]
# ## Deep Learning Model

# %%
# Split the data into train and test sets.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.shape
# Out:
# (1029, 30)

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=30, activation='relu', input_shape=(30, )))
model.add(tf.keras.layers.Dense(units=20, activation='relu'))
model.add(tf.keras.layers.Dense(units=10, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 30)                930
#
#  dense_1 (Dense)             (None, 20)                620
#
#  dense_2 (Dense)             (None, 10)                210
#
#  dense_3 (Dense)             (None, 1)                 11
#
# ...
# Total params: 1,771
# Trainable params: 1,771
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Early stopping.
from keras.callbacks import EarlyStopping
monitor = EarlyStopping(patience=3)

# %%
epochs_hist = model.fit(X_train, y_train, validation_split=0.3, epochs = 50, batch_size = 30, callbacks=[monitor])
# Out:
# Epoch 1/50
# 24/24 [==============================] - 1s 13ms/step - loss: 0.4952 - accuracy: 0.8292 - val_loss: 0.4760 - val_accuracy: 0.8382
# Epoch 2/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4435 - accuracy: 0.8306 - val_loss: 0.4494 - val_accuracy: 0.8382
# Epoch 3/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4170 - accuracy: 0.8306 - val_loss: 0.4401 - val_accuracy: 0.8382
# Epoch 4/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4008 - accuracy: 0.8306 - val_loss: 0.4328 - val_accuracy: 0.8382
# Epoch 5/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3832 - accuracy: 0.8306 - val_loss: 0.4285 - val_accuracy: 0.8382
# Epoch 6/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3662 - accuracy: 0.8306 - val_loss: 0.4251 - val_accuracy: 0.8350
# Epoch 7/50
# ...

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(epochs_hist.history['loss'], label='train')
plt.plot(epochs_hist.history['val_loss'], label='test')
plt.xlabel('Epoch')
plt.title('Training vs. validation loss')
plt.legend()
plt.show()

# %%
plt.plot(epochs_hist.history['accuracy'], label='train')
plt.plot(epochs_hist.history['val_accuracy'], label='test')
plt.title('Model Accuracy Training vs. Testing')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
#p_pred = model.predict(X_test)
#p_pred = p_pred.flatten()
#y_pred = np.where(p_pred > 0.5, 1, 0)    

y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 14/14 [==============================] - 0s 1ms/step

# %%
# Confusion Matrix.
from sklearn.metrics import confusion_matrix, classification_report
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.93       376
#            1       0.65      0.17      0.27        65
#
#     accuracy                           0.86       441
#    macro avg       0.76      0.58      0.60       441
# weighted avg       0.84      0.86      0.83       441
